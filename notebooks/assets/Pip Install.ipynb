# %%
# !pip install /Users/dereksnow/Sovai/GitHub/SovAI/dist/sovai-0.1.6-py3-none-any.whl
# Out:
# Processing /Users/dereksnow/Sovai/GitHub/SovAI/dist/sovai-0.1.6-py3-none-any.whl
# ...
#   Attempting uninstall: sovai
#     Found existing installation: sovai 0.1.1
#     Uninstalling sovai-0.1.1:
#       Successfully uninstalled sovai-0.1.1
# ...

# %%
import sovai as sov

sov.token_auth(token="your_token_here")

df_breakout = sov.data("breakout" )

# %%
df_breakout.query("ticker =='AAPL'")
# Out:
#       ticker       date  target  future_returns  prediction  \
# 11025   AAPL 2021-05-11   1.000           0.158       0.162
# 11026   AAPL 2021-05-12   1.000           0.185       0.162
# 11027   AAPL 2021-05-13   1.000           0.179       0.162
# 11028   AAPL 2021-05-14   1.000           0.153       0.163
# 11029   AAPL 2021-05-17   1.000           0.165       0.162
# ...      ...        ...     ...             ...         ...
# 11826   AAPL 2024-07-18   0.000          -0.025       0.302
# 11827   AAPL 2024-07-19   0.000          -0.026       0.316
# 11828   AAPL 2024-07-22   0.000          -0.024       0.321
# 11829   AAPL 2024-07-23   0.000          -0.029       0.313
# 11830   AAPL 2024-07-24   1.000           0.000       0.313
#
#        bottom_prediction  top_prediction  standard_deviation  \
# 11025              0.153           0.169               0.006
# 11026              0.152           0.169               0.007
# ...
