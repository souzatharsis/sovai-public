# %%
# !pip install sovai[full]

# %% [markdown]
# ## Short Data

# %% [markdown]
# You can run the following commands to retrieve data (`df`) using `sov.data`:
#
# To fetch the **latest data** for a specific query:
#
# ```python
# df = sov.data("query")
# ```
#
# To fetch the **full historical data** for a specific query:
#
# ```python
# df = sov.data("query", full_history=True)
# ```
#
# To fetch the **full data** multiple **tickers** or identifiers like **cusip** and **openfigi**:
#
# ```python
# df = sov.data("query", tickers=["9033434", "IB94343", "43432", "AAPL"])
# ```
#
# To filter **any dataframe** just write some queries:
#
# ```python
# df.filter(["cash_short_term > 10m","start with ticker A","negative profits" ])
# ```

# %%
## To check
import sovai as sov
sov.token_auth(token="visit https://sov.ai/profile for your token")

# %% [markdown]
# ### Short Interest & Overshorted

# %%
df_short = sov.data("short/over_shorted", tickers=["AAPL", "MSFT"])

# %%
df_short.get_latest()
# Out:
#                    over_shorted  over_shorted_chg  short_interest  \
# ticker date
# AAPL   2024-09-13         0.048             0.042   121598768.000
# MSFT   2024-09-13         0.059             0.055    54789104.000
#
#                    number_of_shares  short_percentage  short_prediction  \
# ticker date
# AAPL   2024-09-13   15222587392.000             0.248             0.200
# MSFT   2024-09-13    7371066368.000             0.237             0.178
#
#                    days_to_cover  market_cap   total_revenue       volume
# ticker date
# AAPL   2024-09-13         13.185 3387025.500 85776998400.000 46716568.000
# MSFT   2024-09-13          3.723 3173907.500 64726999040.000 16914014.000

# %% [markdown]
# **Latest Data Full:**

# %%
df_short_all = sov.data("short/over_shorted")

# %%
df_short_all.sort_values("over_shorted")
# Out:
#                    over_shorted  over_shorted_chg  short_interest  \
# ticker date
# INDV   2024-09-13        -0.462            -0.098      224616.984
# TECX   2024-09-13        -0.458             0.016       20909.000
# ASMB   2024-09-13        -0.457            -0.014       10283.000
# INTG   2024-09-13        -0.441            -0.094         122.000
# VOXX   2024-09-13        -0.436             0.021       75883.000
# ...                         ...               ...             ...
# ELWS   2024-09-13         0.521             0.041      478790.031
# ZYXI   2024-09-13         0.531             0.098     5496841.000
# NICK   2024-09-13         0.532             0.165      269016.000
# VSME   2024-09-13         0.536             0.000      580528.000
# SGD    2024-09-13         0.589             0.007     2065248.000
#
#                    number_of_shares  short_percentage  short_prediction  \
# ticker date
# INDV   2024-09-13     130191928.000             0.107             0.569
# TECX   2024-09-13      14335742.000             0.097             0.555
# ASMB   2024-09-13       6336469.000             0.104             0.561
# INTG   2024-09-13       2189218.750             0.011             0.452
# VOXX   2024-09-13      22131980.000             0.159             0.595
# ...                             ...               ...               ...
# ELWS   2024-09-13       2914798.250             0.851             0.330
# ZYXI   2024-09-13      30723926.000             0.856             0.326
# NICK   2024-09-13       7259380.000             0.603             0.071
# VSME   2024-09-13       3245192.250             0.856             0.320
# SGD    2024-09-13      17600000.000             0.819             0.230
#
#                    days_to_cover  market_cap  total_revenue      volume
# ticker date
# INDV   2024-09-13          4.771    1288.900  299000000.000 1071598.375
# TECX   2024-09-13          4.789     257.900          0.000   34373.801
# ASMB   2024-09-13          8.210     114.500          0.000   30506.600
# INTG   2024-09-13        138.474      39.800          0.000   11544.000
# VOXX   2024-09-13         10.617     130.800   91661000.000  391084.594
# ...                          ...         ...            ...         ...
# ELWS   2024-09-13          0.029       6.500   44838912.000   13768.400
# ZYXI   2024-09-13          0.213     250.400   49883000.000   65819.797
# NICK   2024-09-13          0.242      44.500     489000.000    5668.800
# VSME   2024-09-13          0.473       2.700          0.000   47104.398
# SGD    2024-09-13          4.955       4.400      42162.000   49812.199
#
# [6161 rows x 10 columns]

# %% [markdown]
# ### Short Volume

# %%
df_short_volume = sov.data("short/volume", tickers=["AAPL","MSFT"])

# %%
df_short_volume
# Out:
#                    short_volume  total_volume  short_volume_ratio_exchange  \
# ticker date
# AAPL   2011-01-07   8893810.000  19134061.000                        0.461
#        2011-01-14  11789186.000  22008065.000                        0.563
#        2011-01-21  24197268.000  54387222.000                        0.439
#        2011-01-28  13856925.000  31652930.000                        0.487
#        2011-02-04   9718197.000  21816811.000                        0.498
# ...                         ...           ...                          ...
# MSFT   2024-08-16   1727719.000   5593402.000                        0.362
#        2024-08-23   2212624.000   4689151.000                        0.463
#        2024-08-30   1872901.000   4332950.000                        0.399
#        2024-09-06   2528881.000   4666120.000                        0.527
#        2024-09-13   3564699.000   6381448.000                        0.554
#
#                    retail_short_ratio  institutional_short_ratio  \
# ticker date
# AAPL   2011-01-07               0.286                      0.628
#        2011-01-14               0.303                      0.619
#        2011-01-21               0.292                      0.586
#        2011-01-28               0.316                      0.531
#        2011-02-04               0.335                      0.528
# ...                               ...                        ...
# MSFT   2024-08-16               0.030                      0.904
#        2024-08-23               0.044                      0.898
#        2024-08-30               0.027                      0.868
#        2024-09-06               0.034                      0.875
#        2024-09-13               0.022                      0.934
#
#                    market_maker_short_ratio
# ticker date
# AAPL   2011-01-07                     0.086
#        2011-01-14                     0.078
#        2011-01-21                     0.121
#        2011-01-28                     0.153
#        2011-02-04                     0.137
# ...                                     ...
# MSFT   2024-08-16                     0.066
#        2024-08-23                     0.058
#        2024-08-30                     0.105
#        2024-09-06                     0.091
#        2024-09-13                     0.044
#
# [1430 rows x 6 columns]

# %%
df_short_volume.plot_line("short_volume")
# Out:
# Plotting for random tickers. Specify tickers to plot specific data.
