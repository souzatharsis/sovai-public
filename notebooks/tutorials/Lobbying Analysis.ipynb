# %% [markdown]
# ## Lobbying Analysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sovai as sov
sov.token_auth(token="your_token")

# %% [markdown]
# #### Processed Dataset

# %%
# %%time
df_lobbying = sov.data("lobbying/public/", tickers=["WFC","EXPGY"], verbose=True)
# Out:
# /lobbying/public/
# Requesting URL: https://data.sov.ai/lobbying/public/ with params: {'tickers': 'WFC,EXPGY', 'parquet': 'True'}
# Grabbing client side
# CPU times: user 55.3 ms, sys: 33.7 ms, total: 89 ms
# Wall time: 701 ms

# %%
df_lobbying.tail()
# Out:
#                                   client               client_description  \
# ticker date
# WFC    2024-04-22  wells fargo & company                          Banking
#        2024-04-22  wells fargo & company                             None
#        2024-04-22  wells fargo & company                          Banking
#        2024-04-22  wells fargo & company  Banking and Financial Services.
#        2024-05-02  wells fargo & company              Banking and finance
#
#                         spend         transaction_type       filing_type  \
# ticker date
# WFC    2024-04-22   50000.000          lobbying_income  service_provided
#        2024-04-22 1150000.000  direct_lobbying_expense  service_provided
#        2024-04-22   50000.000          lobbying_income  service_provided
#        2024-04-22   30000.000          lobbying_income  service_provided
#        2024-05-02   10000.000          lobbying_income  service_provided
#
# ...
